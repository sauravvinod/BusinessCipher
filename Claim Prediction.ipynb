# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np 
from scipy.stats import zscore
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sn

# Setting pandas print option to limit decimal places to 4
np.set_printoptions(precision=4, linewidth=100)

# %%
# Loading Data
data_df = pd.read_excel('Final Dataset.XLSX')

# %%
#Removing Outliers
data_df['z_score_tc'] = zscore( data_df['Claim Amount'] )
data_df[ ( data_df.z_score_tc > 3.0) | ( data_df.z_score_tc < -3.0) ]
# Out:
# Empty DataFrame
# Columns: [UHID Number, Main Hospital Expenses(y/n), Pre& Post hospital Expense (y/n), Gender , Age, Are you previously covered by any insurance, Policy number, Name of the Hospital, No of days admitted, Type of room admitted, Disease (y/n), Expenses, Are you  covered by any top policy, Are you covered in any other Mediclaim/Helath Insurance, Annual Premium, Does the insurer have internal Claim Process(Y/N), Is the Hospital partnered with the Insurance company, Is_it_routed_through_TPA, Type of Disease/Injury, Policy CSL/Max Limit, Claim Amount, z_score_tc]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# No outliers in the dataset.

# %%
data_df = data_df.drop(['z_score_tc'],axis=1)

# %%
# Identifying Columns
print(data_df.columns)
print("")

# Remove attributes that cannot be predictors - 'Sl.'
data_df = data_df.drop(['UHID Number','Policy number'],axis=1)
# data_df = sm.add_constant( data_df, prepend=True ) 
print(data_df.columns)
# Out:
# Index(['UHID Number', 'Main Hospital Expenses(y/n)',
#        'Pre& Post hospital Expense (y/n)', 'Gender ', 'Age',
#        'Are you previously covered by any insurance', 'Policy number',
#        'Name of the Hospital', 'No of days admitted', 'Type of room admitted',
#        'Disease (y/n)', 'Expenses', 'Are you  covered by any top policy',
#        'Are you covered in any other Mediclaim/Helath Insurance',
#        'Annual Premium', 'Does the insurer have internal Claim Process(Y/N)',
#        'Is the Hospital partnered with the Insurance company',
#        'Is_it_routed_through_TPA', 'Type of Disease/Injury',
#        'Policy CSL/Max Limit', 'Claim Amount'],
#       dtype='object')
#
# Index(['Main Hospital Expenses(y/n)', 'Pre& Post hospital Expense (y/n)',
#        'Gender ', 'Age', 'Are you previously covered by any insurance',
#        'Name of the Hospital', 'No of days admitted', 'Type of room admitted',
#        'Disease (y/n)', 'Expenses', 'Are you  covered by any top policy',
#        'Are you covered in any other Mediclaim/Helath Insurance',
#        'Annual Premium', 'Does the insurer have internal Claim Process(Y/N)',
#        'Is the Hospital partnered with the Insurance company',
#        'Is_it_routed_through_TPA', 'Type of Disease/Injury',
#        'Policy CSL/Max Limit', 'Claim Amount'],
#       dtype='object')

# %%
# Creating Feature Set
 
X_features = ['Main Hospital Expenses(y/n)', 'Pre& Post hospital Expense (y/n)',
       'Gender ', 'Age', 'Are you previously covered by any insurance',
       'Name of the Hospital', 'No of days admitted', 'Type of room admitted',
       'Disease (y/n)', 'Expenses', 'Are you  covered by any top policy',
       'Are you covered in any other Mediclaim/Helath Insurance',
       'Annual Premium', 'Does the insurer have internal Claim Process(Y/N)',
       'Is the Hospital partnered with the Insurance company',
       'Is_it_routed_through_TPA', 'Type of Disease/Injury',
       'Policy CSL/Max Limit']

# %%
# Perform Dummy Coding
encoded_data_df = pd.get_dummies( data_df[X_features],drop_first=True)
list(encoded_data_df.columns)
# Out:
# ['Main Hospital Expenses(y/n)',
#  'Pre& Post hospital Expense (y/n)',
#  'Gender ',
#  'Age',
#  'Are you previously covered by any insurance',
#  'No of days admitted',
#  'Disease (y/n)',
#  'Expenses',
#  'Are you  covered by any top policy',
#  'Are you covered in any other Mediclaim/Helath Insurance',
#  'Annual Premium',
#  'Does the insurer have internal Claim Process(Y/N)',
#  'Is the Hospital partnered with the Insurance company',
#  'Is_it_routed_through_TPA',
#  'Policy CSL/Max Limit',
#  'Name of the Hospital_BAPTIST HEALTH MEDICAL CENTER - LR',
#  'Name of the Hospital_BAPTIST MEDICAL CENTER SOUTH',
#  'Name of the Hospital_CALLAHAN EYE FOUNDATION HOSP',
#  'Name of the Hospital_COOPER GREEN MERCY HOSPITAL',
#  'Name of the Hospital_DCH REGIONAL MEDICAL CENTER',
#  'Name of the Hospital_HUNTSVILLE HOSPITAL',
#  'Name of the Hospital_INFIRMARY WEST',
#  'Name of the Hospital_MOBILE INFIRMARY MEDICAL CENTER',
#  'Name of the Hospital_PRINCETON BAPTIST MEDICAL CENTER',
#  'Name of the Hospital_PROVIDENCE ALASKA MEDICAL CENTER',
#  'Name of the Hospital_PROVIDENCE HOSPITAL',
#  'Name of the Hospital_ST VINCENTS BIRMINGHAM',
#  'Name of the Hospital_ST. VINCENTS EAST',
#  'Name of the Hospital_THE CHILDRENS HOSPITAL OF ALABAMA',
#  'Name of the Hospital_TRINITY MEDICAL CENTER',
#  'Name of the Hospital_UNIV OF SOUTH ALABAMA MEDICAL CENTER',
#  'Name of the Hospital_UNIVERSITY OF ALABAMA HOSPITAL',
#  'Name of the Hospital_USA CHILDRENS AND WOMENS HOSPITAL',
#  'Name of the Hospital_VAUGHAN REGIONAL MEDICAL CENTER',
#  'Type of room admitted_Deluxe',
#  'Type of room admitted_Premium Deluxe',
#  'Type of room admitted_Premium Twin Sharing',
#  'Type of room admitted_Suite',
#  'Type of room admitted_Twin Sharing',
#  'Type of Disease/Injury_Acute',
#  'Type of Disease/Injury_Chronic',
#  'Type of Disease/Injury_Semi-Acute']

# %%
X_features = encoded_data_df.columns
X = encoded_data_df[X_features]
Y = data_df['Claim Amount']

X = sm.add_constant(X,has_constant='add') 

train_X, test_X, train_y, test_y = train_test_split( X , Y, train_size = 0.7, random_state = 42 )
train_X.head()
# Out:
#      const  Main Hospital Expenses(y/n)  Pre& Post hospital Expense (y/n)  \
# 461    1.0                            0                                 1
# 356    1.0                            0                                 1
# 3      1.0                            0                                 1
# 399    1.0                            1                                 0
# 380    1.0                            0                                 1
#
#      Gender   Age  Are you previously covered by any insurance  \
# 461        0   24                                            1
# 356        0   30                                            1
# 3          1   41                                            0
# 399        0   45                                            0
# 380        1   66                                            1
#
#      No of days admitted  Disease (y/n)     Expenses  \
# 461                    1              0   308.143512
# 356                    4              1   416.854055
# 3                      1              1    98.831268
# 399                    6              1  1215.843348
# 380                    5              1  1258.682229
#
#      Are you  covered by any top policy  ...  \
# 461                                   0  ...
# 356                                   0  ...
# 3                                     1  ...
# 399                                   0  ...
# 380                                   0  ...
#
#      Name of the Hospital_USA CHILDRENS AND WOMENS HOSPITAL  \
# 461                                                  0
# 356                                                  0
# 3                                                    0
# 399                                                  0
# 380                                                  0
#
#      Name of the Hospital_VAUGHAN REGIONAL MEDICAL CENTER  \
# 461                                                  0
# 356                                                  0
# 3                                                    0
# 399                                                  0
# 380                                                  0
#
#      Type of room admitted_Deluxe  Type of room admitted_Premium Deluxe  \
# 461                             0                                     0
# 356                             0                                     0
# 3                               0                                     0
# 399                             0                                     0
# 380                             1                                     0
#
#      Type of room admitted_Premium Twin Sharing  Type of room admitted_Suite  \
# 461                                           0                            1
# 356                                           0                            1
# 3                                             0                            1
# 399                                           1                            0
# 380                                           0                            0
#
#      Type of room admitted_Twin Sharing  Type of Disease/Injury_Acute  \
# 461                                   0                             0
# 356                                   0                             0
# 3                                     0                             0
# 399                                   0                             0
# 380                                   0                             1
#
#      Type of Disease/Injury_Chronic  Type of Disease/Injury_Semi-Acute
# 461                               0                                  0
# 356                               0                                  1
# 3                                 0                                  1
# 399                               1                                  0
# 380                               0                                  0
#
# [5 rows x 43 columns]

# %%
# Building the model using training dataset
# Model Building process will take several iterations
model_1 = sm.OLS(train_y, train_X).fit()
model_1.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                       Results: Ordinary least squares
# ===========================================================================================================
# Model:                             OLS                           Adj. R-squared:                  0.999
# Dependent Variable:                Claim Amount                  AIC:                             2530.1977
# Date:                              2021-10-22 02:01              BIC:                             2692.1108
# No. Observations:                  349                           Log-Likelihood:                  -1223.1
# Df Model:                          41                            F-statistic:                     6297.
# Df Residuals:                      307                           Prob (F-statistic):              0.00
# R-squared:                         0.999                         Scale:                           73.664
# -----------------------------------------------------------------------------------------------------------
#                                                            Coef.  Std.Err.    t     P>|t|   [0.025   0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                                     24.8364   4.1327   6.0097 0.0000  16.7044 32.9684
# Main Hospital Expenses(y/n)                                0.1831   1.3776   0.1329 0.8943  -2.5276  2.8938
# Pre& Post hospital Expense (y/n)                           1.5156   1.1291   1.3423 0.1805  -0.7062  3.7374
# Gender                                                     1.3330   0.9671   1.3785 0.1691  -0.5699  3.2359
# Age                                                       -0.4691   0.0301 -15.5918 0.0000  -0.5283 -0.4099
# Are you previously covered by any insurance                0.4860   0.9659   0.5031 0.6152  -1.4146  2.3865
# No of days admitted                                        0.5339   0.1150   4.6434 0.0000   0.3076  0.7601
# Disease (y/n)                                             -1.6823   0.7774  -2.1639 0.0312  -3.2121 -0.1525
# Expenses                                                   0.0144   0.0016   9.2851 0.0000   0.0113  0.0174
# Are you  covered by any top policy                         0.2462   0.9810   0.2510 0.8020  -1.6841  2.1765
# Are you covered in any other Mediclaim/Helath Insurance    1.7848   1.0161   1.7565 0.0800  -0.2146  3.7841
# Annual Premium                                            -0.0013   0.0008  -1.6206 0.1061  -0.0029  0.0003
# Does the insurer have internal Claim Process(Y/N)         -4.1229   1.0338  -3.9882 0.0001  -6.1570 -2.0887
# Is the Hospital partnered with the Insurance company      -4.7850   1.0335  -4.6296 0.0000  -6.8187 -2.7512
# Is_it_routed_through_TPA                                   1.1104   1.1082   1.0020 0.3171  -1.0701  3.2910
# Policy CSL/Max Limit                                       0.8229   0.0023 358.8204 0.0000   0.8184  0.8274
# Name of the Hospital_BAPTIST HEALTH MEDICAL CENTER - LR   -2.6658   3.4496  -0.7728 0.4402  -9.4536  4.1219
# Name of the Hospital_BAPTIST MEDICAL CENTER SOUTH         -5.0379   3.6973  -1.3626 0.1740 -12.3132  2.2374
# Name of the Hospital_CALLAHAN EYE FOUNDATION HOSP         -1.7771   3.2234  -0.5513 0.5818  -8.1198  4.5657
# Name of the Hospital_COOPER GREEN MERCY HOSPITAL          -3.1390   3.0110  -1.0425 0.2980  -9.0638  2.7858
# Name of the Hospital_DCH REGIONAL MEDICAL CENTER          -4.0394   2.9351  -1.3762 0.1697  -9.8147  1.7360
# Name of the Hospital_HUNTSVILLE HOSPITAL                  -1.6361   3.6695  -0.4459 0.6560  -8.8568  5.5845
# Name of the Hospital_INFIRMARY WEST                       -3.7038   3.1199  -1.1872 0.2361  -9.8429  2.4353
# Name of the Hospital_MOBILE INFIRMARY MEDICAL CENTER      -3.6883   3.2213  -1.1450 0.2531 -10.0269  2.6502
# Name of the Hospital_PRINCETON BAPTIST MEDICAL CENTER     -3.4355   3.1219  -1.1005 0.2720  -9.5784  2.7075
# Name of the Hospital_PROVIDENCE ALASKA MEDICAL CENTER     -2.3387   3.1071  -0.7527 0.4522  -8.4526  3.7752
# Name of the Hospital_PROVIDENCE HOSPITAL                  -3.0078   3.3458  -0.8990 0.3694  -9.5915  3.5758
# Name of the Hospital_ST VINCENTS BIRMINGHAM                1.5631   3.2400   0.4824 0.6298  -4.8123  7.9386
# Name of the Hospital_ST. VINCENTS EAST                    -3.9211   3.1575  -1.2418 0.2152 -10.1343  2.2920
# Name of the Hospital_THE CHILDRENS HOSPITAL OF ALABAMA    -0.6006   3.1185  -0.1926 0.8474  -6.7370  5.5359
# Name of the Hospital_TRINITY MEDICAL CENTER               -3.5753   3.0651  -1.1665 0.2443  -9.6065  2.4558
# Name of the Hospital_UNIV OF SOUTH ALABAMA MEDICAL CENTER -3.7294   2.9950  -1.2452 0.2140  -9.6228  2.1639
# Name of the Hospital_UNIVERSITY OF ALABAMA HOSPITAL       -4.4505   3.3219  -1.3397 0.1813 -10.9872  2.0862
# Name of the Hospital_USA CHILDRENS AND WOMENS HOSPITAL    -3.9942   3.2715  -1.2209 0.2231 -10.4316  2.4432
# Name of the Hospital_VAUGHAN REGIONAL MEDICAL CENTER      -0.3484   3.1801  -0.1096 0.9128  -6.6059  5.9091
# Type of room admitted_Deluxe                              -4.1812   1.9295  -2.1670 0.0310  -7.9780 -0.3845
# Type of room admitted_Premium Deluxe                      -1.6988   1.7728  -0.9583 0.3387  -5.1873  1.7896
# Type of room admitted_Premium Twin Sharing                -2.1794   1.8341  -1.1882 0.2357  -5.7884  1.4296
# Type of room admitted_Suite                               -1.4545   1.8924  -0.7686 0.4427  -5.1783  2.2692
# Type of room admitted_Twin Sharing                         0.3852   1.8207   0.2116 0.8326  -3.1973  3.9678
# Type of Disease/Injury_Acute                               1.9304   0.9940   1.9420 0.0531  -0.0256  3.8864
# Type of Disease/Injury_Chronic                            -7.7680   0.9496  -8.1800 0.0000  -9.6366 -5.8994
# Type of Disease/Injury_Semi-Acute                          4.1553   0.9584   4.3357 0.0000   2.2694  6.0411
# -----------------------------------------------------------------------------------------------------------
# Omnibus:                       15.756                 Durbin-Watson:                    2.052
# Prob(Omnibus):                 0.000                  Jarque-Bera (JB):                 37.426
# Skew:                          -0.102                 Prob(JB):                         0.000
# Kurtosis:                      4.591                  Condition No.:                    2241214703922692352
# ===========================================================================================================
# * The condition number is large (2e+18). This might indicate             strong multicollinearity or other
# numerical problems.
# """

# %%
significant_vars = model_1.pvalues.where(model_1.pvalues < 0.05).dropna()
significant_vars = significant_vars.index.tolist()
significant_vars
# Out:
# ['const',
#  'Age',
#  'No of days admitted',
#  'Disease (y/n)',
#  'Expenses',
#  'Does the insurer have internal Claim Process(Y/N)',
#  'Is the Hospital partnered with the Insurance company',
#  'Policy CSL/Max Limit',
#  'Type of room admitted_Deluxe',
#  'Type of Disease/Injury_Chronic',
#  'Type of Disease/Injury_Semi-Acute']

# %%
train_X = train_X[significant_vars]
test_X  = test_X[significant_vars]

model_2 = sm.OLS(train_y, train_X).fit()
model_2.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                    Results: Ordinary least squares
# ======================================================================================================
# Model:                          OLS                          Adj. R-squared:                 0.999
# Dependent Variable:             Claim Amount                 AIC:                            2494.1417
# Date:                           2021-10-22 02:10             BIC:                            2536.5475
# No. Observations:               349                          Log-Likelihood:                 -1236.1
# Df Model:                       10                           F-statistic:                    2.639e+04
# Df Residuals:                   338                          Prob (F-statistic):             0.00
# R-squared:                      0.999                        Scale:                          72.071
# ------------------------------------------------------------------------------------------------------
#                                                       Coef.  Std.Err.    t     P>|t|   [0.025   0.975]
# ------------------------------------------------------------------------------------------------------
# const                                                23.6089   1.8057  13.0744 0.0000  20.0570 27.1608
# Age                                                  -0.4729   0.0286 -16.5293 0.0000  -0.5292 -0.4166
# No of days admitted                                   0.5297   0.1067   4.9630 0.0000   0.3198  0.7396
# Disease (y/n)                                         0.1661   1.3486   0.1232 0.9020  -2.4866  2.8188
# Expenses                                              0.0136   0.0015   9.1867 0.0000   0.0107  0.0165
# Does the insurer have internal Claim Process(Y/N)    -4.5186   0.9220  -4.9008 0.0000  -6.3323 -2.7050
# Is the Hospital partnered with the Insurance company -5.3197   0.9173  -5.7995 0.0000  -7.1240 -3.5155
# Policy CSL/Max Limit                                  0.8232   0.0022 382.0224 0.0000   0.8190  0.8274
# Type of room admitted_Deluxe                         -2.7225   1.2937  -2.1044 0.0361  -5.2672 -0.1777
# Type of Disease/Injury_Chronic                       -9.6903   1.5231  -6.3622 0.0000 -12.6862 -6.6943
# Type of Disease/Injury_Semi-Acute                     2.2823   1.5567   1.4661 0.1436  -0.7798  5.3444
# ------------------------------------------------------------------------------------------------------
# Omnibus:                           13.645                   Durbin-Watson:                      2.057
# Prob(Omnibus):                     0.001                    Jarque-Bera (JB):                   29.636
# Skew:                              -0.090                   Prob(JB):                           0.000
# Kurtosis:                          4.416                    Condition No.:                      3764
# ======================================================================================================
# * The condition number is large (4e+03). This might indicate             strong multicollinearity or
# other numerical problems.
# """
